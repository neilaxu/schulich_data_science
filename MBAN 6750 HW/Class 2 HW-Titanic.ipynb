# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\NeilXu\OneDrive\桌面\MBAN 24 SU\MBAN 6300\week 2 5.15\titanic\train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
plt.hist(df['Pclass'])
# Out:
# (array([216.,   0.,   0.,   0.,   0., 184.,   0.,   0.,   0., 491.]),
#  array([1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4, 2.6, 2.8, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.histplot(df['Pclass'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Count'>

# %%
sns.histplot(df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df['Sex'] = df['Sex'].replace('female',0)
df['Sex'] = df['Sex'].replace('male',1)
# Out:
# C:\Users\NeilXu\AppData\Local\Temp\ipykernel_2384\3030469143.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Sex'] = df['Sex'].replace('male',1)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Sex         Age  \
# count   891.000000  891.000000  891.000000  891.000000  714.000000
# mean    446.000000    0.383838    2.308642    0.647587   29.699118
# std     257.353842    0.486592    0.836071    0.477990   14.526497
# min       1.000000    0.000000    1.000000    0.000000    0.420000
# 25%     223.500000    0.000000    2.000000    0.000000   20.125000
# 50%     446.000000    0.000000    3.000000    1.000000   28.000000
# 75%     668.500000    1.000000    3.000000    1.000000   38.000000
# max     891.000000    1.000000    3.000000    1.000000   80.000000
#
#             SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000
# mean     0.523008    0.381594   32.204208
# std      1.102743    0.806057   49.693429
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    7.910400
# 50%      0.000000    0.000000   14.454200
# 75%      1.000000    0.000000   31.000000
# ...

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
df[df['Fare'] > 512]
# Out:
#      PassengerId  Survived  Pclass                                Name  Sex  \
# 258          259         1       1                    Ward, Miss. Anna    0
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez    1
# 737          738         1       1              Lesurer, Mr. Gustave J    1
#
#       Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  35.0      0      0  PC 17755  512.3292          NaN        C
# 679  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737  35.0      0      0  PC 17755  512.3292         B101        C

# %%
df[df['Embarked'] == 'C']
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 9             10         1       2
# 19            20         1       3
# 26            27         0       3
# 30            31         0       1
# ..           ...       ...     ...
# 866          867         1       2
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 889          890         1       1
#
#                                                   Name  Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 9                  Nasser, Mrs. Nicholas (Adele Achem)    0  14.0      1
# 19                             Masselmani, Mrs. Fatima    0   NaN      0
# 26                             Emir, Mr. Farred Chehab    1   NaN      0
# 30                            Uruchurtu, Don. Manuel E    1  40.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
sns.boxplot(df[df['Pclass'] == 1]['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
df[df['Pclass'] == 1].describe()
# Out:
#        PassengerId    Survived  Pclass         Sex         Age       SibSp  \
# count   216.000000  216.000000   216.0  216.000000  186.000000  216.000000
# mean    461.597222    0.629630     1.0    0.564815   38.233441    0.416667
# std     246.737616    0.484026     0.0    0.496933   14.802856    0.611898
# min       2.000000    0.000000     1.0    0.000000    0.920000    0.000000
# 25%     270.750000    0.000000     1.0    0.000000   27.000000    0.000000
# 50%     472.000000    1.000000     1.0    1.000000   37.000000    0.000000
# 75%     670.500000    1.000000     1.0    1.000000   49.000000    1.000000
# max     890.000000    1.000000     1.0    1.000000   80.000000    3.000000
#
#             Parch        Fare
# count  216.000000  216.000000
# mean     0.356481   84.154687
# std      0.693997   78.380373
# min      0.000000    0.000000
# 25%      0.000000   30.923950
# 50%      0.000000   60.287500
# 75%      0.000000   93.500000
# max      4.000000  512.329200

# %%
column_to_round = 'Fare'
df[column_to_round] = df[column_to_round].round(2)

# %%
fare_to_max = 'Fare'
df[fare_to_max] = df[fare_to_max] = 300
# !!!!!!!!! Wrong !!!!!!!!! changed all the "fare" into 300
